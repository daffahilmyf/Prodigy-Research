# %%
from tqdm import tqdm
import nltk
import re
import contractions
import spacy
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\daffa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\daffa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def text_preprocess(text, options={}):
    
    exclude_words = ["above", "after", "before", "between", "both", "but", "by", "during", "each", "for", "from",
                    "further", "if", "in", "into", "more", "most", "not", "now", "off", "on", "once", "only", "or",
                    "other", "out", "over", "so", "some", "such", "than", "that", "then", "there", "these", "under",
                    "untill", "when", "where", "which", "while", "will", "with", "because"]
    # Lowercase text
    text = text.lower()
    
    # Remove Contraction
    text = contractions.fix(text)
    
    # Remove Punction
    text = re.sub(r'[^\w\s]', ' ', text)
    
    # Tokenize text
    tokens = nltk.word_tokenize(text)
    
    # Remove stopwords
    if options.get("remove_stopwords", True):
        stop_words = set(stopwords.words('english'))

        # Exclude specific conditional words
        if options.get("exclude_conditional_stopwords", True):
            stop_words = set([word for word in stop_words if word not in exclude_words])
        
        tokens = [token for token in tokens if token not in stop_words]
    
    # Lemmatize text
    if options.get("lemmatize", True):
        lemmatizer = WordNetLemmatizer()
        tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    # Stem text
    if options.get("stem", True):
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(token) for token in tokens]
    
    # Join tokens back into text string
    preprocessed_text = ' '.join(tokens)
    
    return preprocessed_text

# %%
def recount_tokens(preproccesing_text):
    tokens = []
    words = preproccesing_text.split()
    start = 0
    for i, word in enumerate(words):
        # Check if word has leading whitespace
        ws = True
        # Add token to list
        tokens.append({
            'text': word,
            'start': start,
            'end': start+len(word),
            'id': i,
            'ws': ws
        })
        # Move start index to next word
        start += len(word) + 1
        
    # Set the ws of the last token to False
    if tokens:
        tokens[-1]['ws'] = False
        
    return tokens

# %%
def get_token_index(text, string_index):
    tokens = text.split()
    token_start_index = 0
    for token in tokens:
        token_end_index = token_start_index + len(token)
        if string_index >= token_start_index and string_index <= token_end_index:
            return tokens.index(token)
        token_start_index = token_end_index + 1
    return -1

# %%
def recount_spans(dataset, preprocess_text, options):
    new_spans = []
    
    if 'spans' in dataset:
    
        for span in dataset['spans']:
            
            start = span['start']
            end = span['end']
            text_pre = text_preprocess(dataset['text'][start:end], options)
            
            new_start = preprocess_text.find(text_pre)
            new_end = new_start + len(text_pre)
            
        
            new_token_start = get_token_index(preprocess_text, new_start)
            new_token_end = get_token_index(preprocess_text, new_end)
            
            new_spans.append({
                'start': new_start,
                'end': new_end,
                'token_start':  new_token_start,
                'token_end': new_token_end,
                'label': span['label']
            })
            
        return new_spans
    return []

# %%
def dataset_preprocessing(input_datasets, options):
    pre_datasets = input_datasets
    for dataset in tqdm(pre_datasets):
        preprocessing_text = text_preprocess(dataset['text'], options=options)
        new_spans = recount_spans(dataset, preprocessing_text, options=options)
        new_tokens = recount_tokens(preprocessing_text)
        
        dataset['text'] = preprocessing_text
        dataset['spans'] = new_spans
        dataset['tokens'] = new_tokens
        
    return pre_datasets

# %%
import json


dataset = []
# Open the file in read mode
with open('./annotated/annotations.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        # Load the JSON data from the file
        dataset.append(json.loads(line.strip()))

# %%
options = {
    'remove_stopwords': True, 
    'lemmatize': True, 
    'stem': True,
    'exclude_conditional_stopwords': True
    }

dataset_preprocessing = dataset_preprocessing(dataset, options)
# Out:
# 100%|██████████| 316/316 [00:00<00:00, 470.38it/s]

# %%
dataset_preprocessing
# Out:
# [{'text': 'within shunt group shall possibl for onli one member group transmit link assur signal time',
#   'spans': [{'start': 0,
#     'end': 18,
#     'token_start': 0,
#     'token_end': 2,
#     'label': 'PRECONDITION'},
#    {'start': 7, 'end': 18, 'token_start': 1, 'token_end': 2, 'label': 'ACTOR'},
#    {'start': 19,
#     'end': 90,
#     'token_start': 3,
#     'token_end': 14,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': '282'},
#   '_input_hash': 456570573,
#   '_task_hash': 1981750695,
#   'tokens': [{'text': 'within', 'start': 0, 'end': 6, 'id': 0, 'ws': True},
#    {'text': 'shunt', 'start': 7, 'end': 12, 'id': 1, 'ws': True},
#    {'text': 'group', 'start': 13, 'end': 18, 'id': 2, 'ws': True},
#    {'text': 'shall', 'start': 19, 'end': 24, 'id': 3, 'ws': True},
#    {'text': 'possibl', 'start': 25, 'end': 32, 'id': 4, 'ws': True},
#    {'text': 'for', 'start': 33, 'end': 36, 'id': 5, 'ws': True},
#    {'text': 'onli', 'start': 37, 'end': 41, 'id': 6, 'ws': True},
#    {'text': 'one', 'start': 42, 'end': 45, 'id': 7, 'ws': True},
#    {'text': 'member', 'start': 46, 'end': 52, 'id': 8, 'ws': True},
#    {'text': 'group', 'start': 53, 'end': 58, 'id': 9, 'ws': True},
#    {'text': 'transmit', 'start': 59, 'end': 67, 'id': 10, 'ws': True},
#    {'text': 'link', 'start': 68, 'end': 72, 'id': 11, 'ws': True},
#    {'text': 'assur', 'start': 73, 'end': 78, 'id': 12, 'ws': True},
#    {'text': 'signal', 'start': 79, 'end': 85, 'id': 13, 'ws': True},
#    {'text': 'time', 'start': 86, 'end': 90, 'id': 14, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'config': {'choice_style': 'single'},
#   'accept': ['BOTH'],
#   'answer': 'accept',
#   '_timestamp': 1676983545},
#  {'text': 'when applic secur domain shall request open load instal extradit delet card content',
#   'spans': [{'start': 0,
#     'end': 11,
#     'token_start': 0,
#     'token_end': 1,
#     'label': 'PRECONDITION'},
#    {'start': 12,
#     'end': 83,
#     'token_start': 2,
#     'token_end': 12,
#     'label': 'POSTCONDITION'},
#    {'start': 12,
#     'end': 24,
#     'token_start': 2,
#     'token_end': 3,
#     'label': 'ACTOR'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 987625400,
#   '_task_hash': 670610515,
#   'tokens': [{'text': 'when', 'start': 0, 'end': 4, 'id': 0, 'ws': True},
#    {'text': 'applic', 'start': 5, 'end': 11, 'id': 1, 'ws': True},
#    {'text': 'secur', 'start': 12, 'end': 17, 'id': 2, 'ws': True},
#    {'text': 'domain', 'start': 18, 'end': 24, 'id': 3, 'ws': True},
#    {'text': 'shall', 'start': 25, 'end': 30, 'id': 4, 'ws': True},
#    {'text': 'request', 'start': 31, 'end': 38, 'id': 5, 'ws': True},
#    {'text': 'open', 'start': 39, 'end': 43, 'id': 6, 'ws': True},
#    {'text': 'load', 'start': 44, 'end': 48, 'id': 7, 'ws': True},
#    {'text': 'instal', 'start': 49, 'end': 55, 'id': 8, 'ws': True},
#    {'text': 'extradit', 'start': 56, 'end': 64, 'id': 9, 'ws': True},
#    {'text': 'delet', 'start': 65, 'end': 70, 'id': 10, 'ws': True},
#    {'text': 'card', 'start': 71, 'end': 75, 'id': 11, 'ws': True},
#    {'text': 'content', 'start': 76, 'end': 83, 'id': 12, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['BOTH'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676983804},
#  {'text': 'bootstrap monitor dpu boot csc shall output error messag r 232 interfac if incorrect number command argument enter',
#   'spans': [{'start': 0,
#     'end': 17,
#     'token_start': 0,
#     'token_end': 1,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 71,
#     'token_start': 0,
#     'token_end': 11,
#     'label': 'POSTCONDITION'},
#    {'start': 72,
#     'end': 114,
#     'token_start': 12,
#     'token_end': 17,
#     'label': 'PRECONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 1799345027,
#   '_task_hash': 1417195684,
#   'tokens': [{'text': 'bootstrap', 'start': 0, 'end': 9, 'id': 0, 'ws': True},
#    {'text': 'monitor', 'start': 10, 'end': 17, 'id': 1, 'ws': True},
#    {'text': 'dpu', 'start': 18, 'end': 21, 'id': 2, 'ws': True},
#    {'text': 'boot', 'start': 22, 'end': 26, 'id': 3, 'ws': True},
#    {'text': 'csc', 'start': 27, 'end': 30, 'id': 4, 'ws': True},
#    {'text': 'shall', 'start': 31, 'end': 36, 'id': 5, 'ws': True},
#    {'text': 'output', 'start': 37, 'end': 43, 'id': 6, 'ws': True},
#    {'text': 'error', 'start': 44, 'end': 49, 'id': 7, 'ws': True},
#    {'text': 'messag', 'start': 50, 'end': 56, 'id': 8, 'ws': True},
#    {'text': 'r', 'start': 57, 'end': 58, 'id': 9, 'ws': True},
#    {'text': '232', 'start': 59, 'end': 62, 'id': 10, 'ws': True},
#    {'text': 'interfac', 'start': 63, 'end': 71, 'id': 11, 'ws': True},
#    {'text': 'if', 'start': 72, 'end': 74, 'id': 12, 'ws': True},
#    {'text': 'incorrect', 'start': 75, 'end': 84, 'id': 13, 'ws': True},
#    {'text': 'number', 'start': 85, 'end': 91, 'id': 14, 'ws': True},
#    {'text': 'command', 'start': 92, 'end': 99, 'id': 15, 'ws': True},
#    {'text': 'argument', 'start': 100, 'end': 108, 'id': 16, 'ws': True},
#    {'text': 'enter', 'start': 109, 'end': 114, 'id': 17, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['BOTH'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676983826},
#  {'text': 'dpu scui shall capabl prepar one stpdu for deliveri scu everi millisecond or shall indic data condit scu by maintain un increment st_pdu transfer request counter field',
#   'spans': [{'start': 0,
#     'end': 8,
#     'token_start': 0,
#     'token_end': 1,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 73,
#     'token_start': 0,
#     'token_end': 11,
#     'label': 'POSTCONDITION'},
#    {'start': 43,
#     'end': 73,
#     'token_start': 8,
#     'token_end': 11,
#     'label': 'QUALITY'},
#    {'start': 77,
#     'end': 167,
#     'token_start': 2,
#     'token_end': 26,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': -411322862,
#   '_task_hash': -1653686040,
#   'tokens': [{'text': 'dpu', 'start': 0, 'end': 3, 'id': 0, 'ws': True},
#    {'text': 'scui', 'start': 4, 'end': 8, 'id': 1, 'ws': True},
#    {'text': 'shall', 'start': 9, 'end': 14, 'id': 2, 'ws': True},
#    {'text': 'capabl', 'start': 15, 'end': 21, 'id': 3, 'ws': True},
#    {'text': 'prepar', 'start': 22, 'end': 28, 'id': 4, 'ws': True},
#    {'text': 'one', 'start': 29, 'end': 32, 'id': 5, 'ws': True},
#    {'text': 'stpdu', 'start': 33, 'end': 38, 'id': 6, 'ws': True},
#    {'text': 'for', 'start': 39, 'end': 42, 'id': 7, 'ws': True},
#    {'text': 'deliveri', 'start': 43, 'end': 51, 'id': 8, 'ws': True},
#    {'text': 'scu', 'start': 52, 'end': 55, 'id': 9, 'ws': True},
#    {'text': 'everi', 'start': 56, 'end': 61, 'id': 10, 'ws': True},
#    {'text': 'millisecond', 'start': 62, 'end': 73, 'id': 11, 'ws': True},
#    {'text': 'or', 'start': 74, 'end': 76, 'id': 12, 'ws': True},
#    {'text': 'shall', 'start': 77, 'end': 82, 'id': 13, 'ws': True},
#    {'text': 'indic', 'start': 83, 'end': 88, 'id': 14, 'ws': True},
#    {'text': 'data', 'start': 89, 'end': 93, 'id': 15, 'ws': True},
#    {'text': 'condit', 'start': 94, 'end': 100, 'id': 16, 'ws': True},
#    {'text': 'scu', 'start': 101, 'end': 104, 'id': 17, 'ws': True},
#    {'text': 'by', 'start': 105, 'end': 107, 'id': 18, 'ws': True},
#    {'text': 'maintain', 'start': 108, 'end': 116, 'id': 19, 'ws': True},
#    {'text': 'un', 'start': 117, 'end': 119, 'id': 20, 'ws': True},
#    {'text': 'increment', 'start': 120, 'end': 129, 'id': 21, 'ws': True},
#    {'text': 'st_pdu', 'start': 130, 'end': 136, 'id': 22, 'ws': True},
#    {'text': 'transfer', 'start': 137, 'end': 145, 'id': 23, 'ws': True},
#    {'text': 'request', 'start': 146, 'end': 153, 'id': 24, 'ws': True},
#    {'text': 'counter', 'start': 154, 'end': 161, 'id': 25, 'ws': True},
#    {'text': 'field', 'start': 162, 'end': 167, 'id': 26, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676983858},
#  {'text': 'scheme provid must assign uniqu identifi number merchant acquir provid psam',
#   'spans': [{'start': 0,
#     'end': 13,
#     'token_start': 0,
#     'token_end': 1,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 75,
#     'token_start': 0,
#     'token_end': 10,
#     'label': 'POSTCONDITION'},
#    {'start': 48,
#     'end': 63,
#     'token_start': 7,
#     'token_end': 8,
#     'label': 'ACTOR'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 1092137817,
#   '_task_hash': 1875827168,
#   'tokens': [{'text': 'scheme', 'start': 0, 'end': 6, 'id': 0, 'ws': True},
#    {'text': 'provid', 'start': 7, 'end': 13, 'id': 1, 'ws': True},
#    {'text': 'must', 'start': 14, 'end': 18, 'id': 2, 'ws': True},
#    {'text': 'assign', 'start': 19, 'end': 25, 'id': 3, 'ws': True},
#    {'text': 'uniqu', 'start': 26, 'end': 31, 'id': 4, 'ws': True},
#    {'text': 'identifi', 'start': 32, 'end': 40, 'id': 5, 'ws': True},
#    {'text': 'number', 'start': 41, 'end': 47, 'id': 6, 'ws': True},
#    {'text': 'merchant', 'start': 48, 'end': 56, 'id': 7, 'ws': True},
#    {'text': 'acquir', 'start': 57, 'end': 63, 'id': 8, 'ws': True},
#    {'text': 'provid', 'start': 64, 'end': 70, 'id': 9, 'ws': True},
#    {'text': 'psam', 'start': 71, 'end': 75, 'id': 10, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676983875},
#  {'text': 'if automat network select implement shall possibl for driver activ deactiv automat network select',
#   'spans': [{'start': 0,
#     'end': 35,
#     'token_start': 0,
#     'token_end': 4,
#     'label': 'PRECONDITION'},
#    {'start': 36,
#     'end': 97,
#     'token_start': 5,
#     'token_end': 3,
#     'label': 'POSTCONDITION'},
#    {'start': 54,
#     'end': 60,
#     'token_start': 8,
#     'token_end': 8,
#     'label': 'ACTOR'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 1863588751,
#   '_task_hash': 665215475,
#   'tokens': [{'text': 'if', 'start': 0, 'end': 2, 'id': 0, 'ws': True},
#    {'text': 'automat', 'start': 3, 'end': 10, 'id': 1, 'ws': True},
#    {'text': 'network', 'start': 11, 'end': 18, 'id': 2, 'ws': True},
#    {'text': 'select', 'start': 19, 'end': 25, 'id': 3, 'ws': True},
#    {'text': 'implement', 'start': 26, 'end': 35, 'id': 4, 'ws': True},
#    {'text': 'shall', 'start': 36, 'end': 41, 'id': 5, 'ws': True},
#    {'text': 'possibl', 'start': 42, 'end': 49, 'id': 6, 'ws': True},
#    {'text': 'for', 'start': 50, 'end': 53, 'id': 7, 'ws': True},
#    {'text': 'driver', 'start': 54, 'end': 60, 'id': 8, 'ws': True},
#    {'text': 'activ', 'start': 61, 'end': 66, 'id': 9, 'ws': True},
#    {'text': 'deactiv', 'start': 67, 'end': 74, 'id': 10, 'ws': True},
#    {'text': 'automat', 'start': 75, 'end': 82, 'id': 11, 'ws': True},
#    {'text': 'network', 'start': 83, 'end': 90, 'id': 12, 'ws': True},
#    {'text': 'select', 'start': 91, 'end': 97, 'id': 13, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['BOTH'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676983936},
#  {'text': 'system shall oper within window xp profession oper system',
#   'spans': [{'start': 0,
#     'end': 6,
#     'token_start': 0,
#     'token_end': 0,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 57,
#     'token_start': 0,
#     'token_end': 0,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 1232373520,
#   '_task_hash': 2045372575,
#   'tokens': [{'text': 'system', 'start': 0, 'end': 6, 'id': 0, 'ws': True},
#    {'text': 'shall', 'start': 7, 'end': 12, 'id': 1, 'ws': True},
#    {'text': 'oper', 'start': 13, 'end': 17, 'id': 2, 'ws': True},
#    {'text': 'within', 'start': 18, 'end': 24, 'id': 3, 'ws': True},
#    {'text': 'window', 'start': 25, 'end': 31, 'id': 4, 'ws': True},
#    {'text': 'xp', 'start': 32, 'end': 34, 'id': 5, 'ws': True},
#    {'text': 'profession', 'start': 35, 'end': 45, 'id': 6, 'ws': True},
#    {'text': 'oper', 'start': 46, 'end': 50, 'id': 7, 'ws': True},
#    {'text': 'system', 'start': 51, 'end': 57, 'id': 8, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984012},
#  {'text': 'vcd system must provid user interfac econom oper for upload exist vcd packag',
#   'spans': [{'start': 0,
#     'end': 76,
#     'token_start': 0,
#     'token_end': 12,
#     'label': 'POSTCONDITION'},
#    {'start': 0,
#     'end': 10,
#     'token_start': 0,
#     'token_end': 1,
#     'label': 'ACTOR'}],
#   'meta': {'pattern': '237'},
#   '_input_hash': 757919458,
#   '_task_hash': 1859430863,
#   'tokens': [{'text': 'vcd', 'start': 0, 'end': 3, 'id': 0, 'ws': True},
#    {'text': 'system', 'start': 4, 'end': 10, 'id': 1, 'ws': True},
#    {'text': 'must', 'start': 11, 'end': 15, 'id': 2, 'ws': True},
#    {'text': 'provid', 'start': 16, 'end': 22, 'id': 3, 'ws': True},
#    {'text': 'user', 'start': 23, 'end': 27, 'id': 4, 'ws': True},
#    {'text': 'interfac', 'start': 28, 'end': 36, 'id': 5, 'ws': True},
#    {'text': 'econom', 'start': 37, 'end': 43, 'id': 6, 'ws': True},
#    {'text': 'oper', 'start': 44, 'end': 48, 'id': 7, 'ws': True},
#    {'text': 'for', 'start': 49, 'end': 52, 'id': 8, 'ws': True},
#    {'text': 'upload', 'start': 53, 'end': 59, 'id': 9, 'ws': True},
#    {'text': 'exist', 'start': 60, 'end': 65, 'id': 10, 'ws': True},
#    {'text': 'vcd', 'start': 66, 'end': 69, 'id': 11, 'ws': True},
#    {'text': 'packag', 'start': 70, 'end': 76, 'id': 12, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984039},
#  {'text': 'in order fulfil requir some railway possibl provid altern mean link assur indic',
#   'spans': [{'start': 0,
#     'end': 35,
#     'token_start': 0,
#     'token_end': 5,
#     'label': 'PRECONDITION'},
#    {'start': 36,
#     'end': 79,
#     'token_start': 6,
#     'token_end': 12,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 2092507399,
#   '_task_hash': 208484880,
#   'tokens': [{'text': 'in', 'start': 0, 'end': 2, 'id': 0, 'ws': True},
#    {'text': 'order', 'start': 3, 'end': 8, 'id': 1, 'ws': True},
#    {'text': 'fulfil', 'start': 9, 'end': 15, 'id': 2, 'ws': True},
#    {'text': 'requir', 'start': 16, 'end': 22, 'id': 3, 'ws': True},
#    {'text': 'some', 'start': 23, 'end': 27, 'id': 4, 'ws': True},
#    {'text': 'railway', 'start': 28, 'end': 35, 'id': 5, 'ws': True},
#    {'text': 'possibl', 'start': 36, 'end': 43, 'id': 6, 'ws': True},
#    {'text': 'provid', 'start': 44, 'end': 50, 'id': 7, 'ws': True},
#    {'text': 'altern', 'start': 51, 'end': 57, 'id': 8, 'ws': True},
#    {'text': 'mean', 'start': 58, 'end': 62, 'id': 9, 'ws': True},
#    {'text': 'link', 'start': 63, 'end': 67, 'id': 10, 'ws': True},
#    {'text': 'assur', 'start': 68, 'end': 73, 'id': 11, 'ws': True},
#    {'text': 'indic', 'start': 74, 'end': 79, 'id': 12, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['BOTH'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984069},
#  {'text': 'radio shall support least ten differ languag',
#   'spans': [{'start': 0,
#     'end': 44,
#     'token_start': 0,
#     'token_end': 6,
#     'label': 'POSTCONDITION'},
#    {'start': 0, 'end': 5, 'token_start': 0, 'token_end': 0, 'label': 'ACTOR'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 847863758,
#   '_task_hash': 1860633636,
#   'tokens': [{'text': 'radio', 'start': 0, 'end': 5, 'id': 0, 'ws': True},
#    {'text': 'shall', 'start': 6, 'end': 11, 'id': 1, 'ws': True},
#    {'text': 'support', 'start': 12, 'end': 19, 'id': 2, 'ws': True},
#    {'text': 'least', 'start': 20, 'end': 25, 'id': 3, 'ws': True},
#    {'text': 'ten', 'start': 26, 'end': 29, 'id': 4, 'ws': True},
#    {'text': 'differ', 'start': 30, 'end': 36, 'id': 5, 'ws': True},
#    {'text': 'languag', 'start': 37, 'end': 44, 'id': 6, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984080},
#  {'text': 'if call fail in lead traction vehicl lead driver will respons for establish call if call fail other cab driver in that cab will call lead cab request establish call',
#   'spans': [{'start': 0,
#     'end': 36,
#     'token_start': 0,
#     'token_end': 6,
#     'label': 'PRECONDITION'},
#    {'start': 37,
#     'end': 80,
#     'token_start': 4,
#     'token_end': 1,
#     'label': 'POSTCONDITION'},
#    {'start': 81,
#     'end': 103,
#     'token_start': 0,
#     'token_end': 18,
#     'label': 'PRECONDITION'},
#    {'start': 104,
#     'end': 164,
#     'token_start': 8,
#     'token_end': 1,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 1324972005,
#   '_task_hash': -158884749,
#   'tokens': [{'text': 'if', 'start': 0, 'end': 2, 'id': 0, 'ws': True},
#    {'text': 'call', 'start': 3, 'end': 7, 'id': 1, 'ws': True},
#    {'text': 'fail', 'start': 8, 'end': 12, 'id': 2, 'ws': True},
#    {'text': 'in', 'start': 13, 'end': 15, 'id': 3, 'ws': True},
#    {'text': 'lead', 'start': 16, 'end': 20, 'id': 4, 'ws': True},
#    {'text': 'traction', 'start': 21, 'end': 29, 'id': 5, 'ws': True},
#    {'text': 'vehicl', 'start': 30, 'end': 36, 'id': 6, 'ws': True},
#    {'text': 'lead', 'start': 37, 'end': 41, 'id': 7, 'ws': True},
#    {'text': 'driver', 'start': 42, 'end': 48, 'id': 8, 'ws': True},
#    {'text': 'will', 'start': 49, 'end': 53, 'id': 9, 'ws': True},
#    {'text': 'respons', 'start': 54, 'end': 61, 'id': 10, 'ws': True},
#    {'text': 'for', 'start': 62, 'end': 65, 'id': 11, 'ws': True},
#    {'text': 'establish', 'start': 66, 'end': 75, 'id': 12, 'ws': True},
#    {'text': 'call', 'start': 76, 'end': 80, 'id': 13, 'ws': True},
#    {'text': 'if', 'start': 81, 'end': 83, 'id': 14, 'ws': True},
#    {'text': 'call', 'start': 84, 'end': 88, 'id': 15, 'ws': True},
#    {'text': 'fail', 'start': 89, 'end': 93, 'id': 16, 'ws': True},
#    {'text': 'other', 'start': 94, 'end': 99, 'id': 17, 'ws': True},
#    {'text': 'cab', 'start': 100, 'end': 103, 'id': 18, 'ws': True},
#    {'text': 'driver', 'start': 104, 'end': 110, 'id': 19, 'ws': True},
#    {'text': 'in', 'start': 111, 'end': 113, 'id': 20, 'ws': True},
#    {'text': 'that', 'start': 114, 'end': 118, 'id': 21, 'ws': True},
#    {'text': 'cab', 'start': 119, 'end': 122, 'id': 22, 'ws': True},
#    {'text': 'will', 'start': 123, 'end': 127, 'id': 23, 'ws': True},
#    {'text': 'call', 'start': 128, 'end': 132, 'id': 24, 'ws': True},
#    {'text': 'lead', 'start': 133, 'end': 137, 'id': 25, 'ws': True},
#    {'text': 'cab', 'start': 138, 'end': 141, 'id': 26, 'ws': True},
#    {'text': 'request', 'start': 142, 'end': 149, 'id': 27, 'ws': True},
#    {'text': 'establish', 'start': 150, 'end': 159, 'id': 28, 'ws': True},
#    {'text': 'call', 'start': 160, 'end': 164, 'id': 29, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['BOTH'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984114},
#  {'text': 'cng shall classifi packet enter cpn wan interfac downstream direct accord number predefin prioriti classif done on basi differ layer 2 or layer 3 paramet',
#   'spans': [{'start': 0,
#     'end': 3,
#     'token_start': 0,
#     'token_end': 0,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 98,
#     'token_start': 0,
#     'token_end': 13,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': -1750515136,
#   '_task_hash': -1594761081,
#   'tokens': [{'text': 'cng', 'start': 0, 'end': 3, 'id': 0, 'ws': True},
#    {'text': 'shall', 'start': 4, 'end': 9, 'id': 1, 'ws': True},
#    {'text': 'classifi', 'start': 10, 'end': 18, 'id': 2, 'ws': True},
#    {'text': 'packet', 'start': 19, 'end': 25, 'id': 3, 'ws': True},
#    {'text': 'enter', 'start': 26, 'end': 31, 'id': 4, 'ws': True},
#    {'text': 'cpn', 'start': 32, 'end': 35, 'id': 5, 'ws': True},
#    {'text': 'wan', 'start': 36, 'end': 39, 'id': 6, 'ws': True},
#    {'text': 'interfac', 'start': 40, 'end': 48, 'id': 7, 'ws': True},
#    {'text': 'downstream', 'start': 49, 'end': 59, 'id': 8, 'ws': True},
#    {'text': 'direct', 'start': 60, 'end': 66, 'id': 9, 'ws': True},
#    {'text': 'accord', 'start': 67, 'end': 73, 'id': 10, 'ws': True},
#    {'text': 'number', 'start': 74, 'end': 80, 'id': 11, 'ws': True},
#    {'text': 'predefin', 'start': 81, 'end': 89, 'id': 12, 'ws': True},
#    {'text': 'prioriti', 'start': 90, 'end': 98, 'id': 13, 'ws': True},
#    {'text': 'classif', 'start': 99, 'end': 106, 'id': 14, 'ws': True},
#    {'text': 'done', 'start': 107, 'end': 111, 'id': 15, 'ws': True},
#    {'text': 'on', 'start': 112, 'end': 114, 'id': 16, 'ws': True},
#    {'text': 'basi', 'start': 115, 'end': 119, 'id': 17, 'ws': True},
#    {'text': 'differ', 'start': 120, 'end': 126, 'id': 18, 'ws': True},
#    {'text': 'layer', 'start': 127, 'end': 132, 'id': 19, 'ws': True},
#    {'text': '2', 'start': 133, 'end': 134, 'id': 20, 'ws': True},
#    {'text': 'or', 'start': 135, 'end': 137, 'id': 21, 'ws': True},
#    {'text': 'layer', 'start': 138, 'end': 143, 'id': 22, 'ws': True},
#    {'text': '3', 'start': 144, 'end': 145, 'id': 23, 'ws': True},
#    {'text': 'paramet', 'start': 146, 'end': 153, 'id': 24, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984139},
#  {'text': 'dpu adc csc shall address hardwar modul defin in document 1400 compani x specif for compani x commun memori modul',
#   'spans': [{'start': 0,
#     'end': 11,
#     'token_start': 0,
#     'token_end': 2,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 113,
#     'token_start': 0,
#     'token_end': 6,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': '244, 244'},
#   '_input_hash': -1336199768,
#   '_task_hash': -728552388,
#   'tokens': [{'text': 'dpu', 'start': 0, 'end': 3, 'id': 0, 'ws': True},
#    {'text': 'adc', 'start': 4, 'end': 7, 'id': 1, 'ws': True},
#    {'text': 'csc', 'start': 8, 'end': 11, 'id': 2, 'ws': True},
#    {'text': 'shall', 'start': 12, 'end': 17, 'id': 3, 'ws': True},
#    {'text': 'address', 'start': 18, 'end': 25, 'id': 4, 'ws': True},
#    {'text': 'hardwar', 'start': 26, 'end': 33, 'id': 5, 'ws': True},
#    {'text': 'modul', 'start': 34, 'end': 39, 'id': 6, 'ws': True},
#    {'text': 'defin', 'start': 40, 'end': 45, 'id': 7, 'ws': True},
#    {'text': 'in', 'start': 46, 'end': 48, 'id': 8, 'ws': True},
#    {'text': 'document', 'start': 49, 'end': 57, 'id': 9, 'ws': True},
#    {'text': '1400', 'start': 58, 'end': 62, 'id': 10, 'ws': True},
#    {'text': 'compani', 'start': 63, 'end': 70, 'id': 11, 'ws': True},
#    {'text': 'x', 'start': 71, 'end': 72, 'id': 12, 'ws': True},
#    {'text': 'specif', 'start': 73, 'end': 79, 'id': 13, 'ws': True},
#    {'text': 'for', 'start': 80, 'end': 83, 'id': 14, 'ws': True},
#    {'text': 'compani', 'start': 84, 'end': 91, 'id': 15, 'ws': True},
#    {'text': 'x', 'start': 92, 'end': 93, 'id': 16, 'ws': True},
#    {'text': 'commun', 'start': 94, 'end': 100, 'id': 17, 'ws': True},
#    {'text': 'memori', 'start': 101, 'end': 107, 'id': 18, 'ws': True},
#    {'text': 'modul', 'start': 108, 'end': 113, 'id': 19, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984155},
#  {'text': 'card use uniqu diversifi secret key person into card gener authent transact signatur',
#   'spans': [{'start': 0,
#     'end': 84,
#     'token_start': 0,
#     'token_end': 12,
#     'label': 'POSTCONDITION'},
#    {'start': 0, 'end': 4, 'token_start': 0, 'token_end': 0, 'label': 'ACTOR'}],
#   'meta': {'pattern': ''},
#   '_input_hash': -346305625,
#   '_task_hash': 977527107,
#   'tokens': [{'text': 'card', 'start': 0, 'end': 4, 'id': 0, 'ws': True},
#    {'text': 'use', 'start': 5, 'end': 8, 'id': 1, 'ws': True},
#    {'text': 'uniqu', 'start': 9, 'end': 14, 'id': 2, 'ws': True},
#    {'text': 'diversifi', 'start': 15, 'end': 24, 'id': 3, 'ws': True},
#    {'text': 'secret', 'start': 25, 'end': 31, 'id': 4, 'ws': True},
#    {'text': 'key', 'start': 32, 'end': 35, 'id': 5, 'ws': True},
#    {'text': 'person', 'start': 36, 'end': 42, 'id': 6, 'ws': True},
#    {'text': 'into', 'start': 43, 'end': 47, 'id': 7, 'ws': True},
#    {'text': 'card', 'start': 48, 'end': 52, 'id': 8, 'ws': True},
#    {'text': 'gener', 'start': 53, 'end': 58, 'id': 9, 'ws': True},
#    {'text': 'authent', 'start': 59, 'end': 66, 'id': 10, 'ws': True},
#    {'text': 'transact', 'start': 67, 'end': 75, 'id': 11, 'ws': True},
#    {'text': 'signatur', 'start': 76, 'end': 84, 'id': 12, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984187},
#  {'text': 'psam must creat mac on updat aggreg record aggreg record by card issuer must store in psam may also store in po devic well',
#   'spans': [{'start': 0,
#     'end': 4,
#     'token_start': 0,
#     'token_end': 0,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 90,
#     'token_start': 0,
#     'token_end': 0,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': -680114057,
#   '_task_hash': -1172129366,
#   'tokens': [{'text': 'psam', 'start': 0, 'end': 4, 'id': 0, 'ws': True},
#    {'text': 'must', 'start': 5, 'end': 9, 'id': 1, 'ws': True},
#    {'text': 'creat', 'start': 10, 'end': 15, 'id': 2, 'ws': True},
#    {'text': 'mac', 'start': 16, 'end': 19, 'id': 3, 'ws': True},
#    {'text': 'on', 'start': 20, 'end': 22, 'id': 4, 'ws': True},
#    {'text': 'updat', 'start': 23, 'end': 28, 'id': 5, 'ws': True},
#    {'text': 'aggreg', 'start': 29, 'end': 35, 'id': 6, 'ws': True},
#    {'text': 'record', 'start': 36, 'end': 42, 'id': 7, 'ws': True},
#    {'text': 'aggreg', 'start': 43, 'end': 49, 'id': 8, 'ws': True},
#    {'text': 'record', 'start': 50, 'end': 56, 'id': 9, 'ws': True},
#    {'text': 'by', 'start': 57, 'end': 59, 'id': 10, 'ws': True},
#    {'text': 'card', 'start': 60, 'end': 64, 'id': 11, 'ws': True},
#    {'text': 'issuer', 'start': 65, 'end': 71, 'id': 12, 'ws': True},
#    {'text': 'must', 'start': 72, 'end': 76, 'id': 13, 'ws': True},
#    {'text': 'store', 'start': 77, 'end': 82, 'id': 14, 'ws': True},
#    {'text': 'in', 'start': 83, 'end': 85, 'id': 15, 'ws': True},
#    {'text': 'psam', 'start': 86, 'end': 90, 'id': 16, 'ws': True},
#    {'text': 'may', 'start': 91, 'end': 94, 'id': 17, 'ws': True},
#    {'text': 'also', 'start': 95, 'end': 99, 'id': 18, 'ws': True},
#    {'text': 'store', 'start': 100, 'end': 105, 'id': 19, 'ws': True},
#    {'text': 'in', 'start': 106, 'end': 108, 'id': 20, 'ws': True},
#    {'text': 'po', 'start': 109, 'end': 111, 'id': 21, 'ws': True},
#    {'text': 'devic', 'start': 112, 'end': 117, 'id': 22, 'ws': True},
#    {'text': 'well', 'start': 118, 'end': 122, 'id': 23, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984199},
#  {'text': 'develop team shall requir adjust exist sourc code use externallog file onli if that sourc code must modifi implement anoth requir',
#   'spans': [{'start': 0,
#     'end': 12,
#     'token_start': 0,
#     'token_end': 1,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 70,
#     'token_start': 0,
#     'token_end': 10,
#     'label': 'POSTCONDITION'},
#    {'start': 71,
#     'end': 129,
#     'token_start': 11,
#     'token_end': 3,
#     'label': 'PRECONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': -1386255493,
#   '_task_hash': -332861318,
#   'tokens': [{'text': 'develop', 'start': 0, 'end': 7, 'id': 0, 'ws': True},
#    {'text': 'team', 'start': 8, 'end': 12, 'id': 1, 'ws': True},
#    {'text': 'shall', 'start': 13, 'end': 18, 'id': 2, 'ws': True},
#    {'text': 'requir', 'start': 19, 'end': 25, 'id': 3, 'ws': True},
#    {'text': 'adjust', 'start': 26, 'end': 32, 'id': 4, 'ws': True},
#    {'text': 'exist', 'start': 33, 'end': 38, 'id': 5, 'ws': True},
#    {'text': 'sourc', 'start': 39, 'end': 44, 'id': 6, 'ws': True},
#    {'text': 'code', 'start': 45, 'end': 49, 'id': 7, 'ws': True},
#    {'text': 'use', 'start': 50, 'end': 53, 'id': 8, 'ws': True},
#    {'text': 'externallog', 'start': 54, 'end': 65, 'id': 9, 'ws': True},
#    {'text': 'file', 'start': 66, 'end': 70, 'id': 10, 'ws': True},
#    {'text': 'onli', 'start': 71, 'end': 75, 'id': 11, 'ws': True},
#    {'text': 'if', 'start': 76, 'end': 78, 'id': 12, 'ws': True},
#    {'text': 'that', 'start': 79, 'end': 83, 'id': 13, 'ws': True},
#    {'text': 'sourc', 'start': 84, 'end': 89, 'id': 14, 'ws': True},
#    {'text': 'code', 'start': 90, 'end': 94, 'id': 15, 'ws': True},
#    {'text': 'must', 'start': 95, 'end': 99, 'id': 16, 'ws': True},
#    {'text': 'modifi', 'start': 100, 'end': 106, 'id': 17, 'ws': True},
#    {'text': 'implement', 'start': 107, 'end': 116, 'id': 18, 'ws': True},
#    {'text': 'anoth', 'start': 117, 'end': 122, 'id': 19, 'ws': True},
#    {'text': 'requir', 'start': 123, 'end': 129, 'id': 20, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['BOTH'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984220},
#  {'text': 'disput applic must conform legal requir specifi by regul e regul z that govern credit card disput process',
#   'spans': [{'start': 0,
#     'end': 13,
#     'token_start': 0,
#     'token_end': 1,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 105,
#     'token_start': 0,
#     'token_end': 17,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 1081225053,
#   '_task_hash': -1955364591,
#   'tokens': [{'text': 'disput', 'start': 0, 'end': 6, 'id': 0, 'ws': True},
#    {'text': 'applic', 'start': 7, 'end': 13, 'id': 1, 'ws': True},
#    {'text': 'must', 'start': 14, 'end': 18, 'id': 2, 'ws': True},
#    {'text': 'conform', 'start': 19, 'end': 26, 'id': 3, 'ws': True},
#    {'text': 'legal', 'start': 27, 'end': 32, 'id': 4, 'ws': True},
#    {'text': 'requir', 'start': 33, 'end': 39, 'id': 5, 'ws': True},
#    {'text': 'specifi', 'start': 40, 'end': 47, 'id': 6, 'ws': True},
#    {'text': 'by', 'start': 48, 'end': 50, 'id': 7, 'ws': True},
#    {'text': 'regul', 'start': 51, 'end': 56, 'id': 8, 'ws': True},
#    {'text': 'e', 'start': 57, 'end': 58, 'id': 9, 'ws': True},
#    {'text': 'regul', 'start': 59, 'end': 64, 'id': 10, 'ws': True},
#    {'text': 'z', 'start': 65, 'end': 66, 'id': 11, 'ws': True},
#    {'text': 'that', 'start': 67, 'end': 71, 'id': 12, 'ws': True},
#    {'text': 'govern', 'start': 72, 'end': 78, 'id': 13, 'ws': True},
#    {'text': 'credit', 'start': 79, 'end': 85, 'id': 14, 'ws': True},
#    {'text': 'card', 'start': 86, 'end': 90, 'id': 15, 'ws': True},
#    {'text': 'disput', 'start': 91, 'end': 97, 'id': 16, 'ws': True},
#    {'text': 'process', 'start': 98, 'end': 105, 'id': 17, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984235},
#  {'text': 'contain detail transact between initi command for that transact initi command for next transact',
#   'spans': [],
#   'meta': {'pattern': ''},
#   '_input_hash': 1656954099,
#   '_task_hash': 1080743984,
#   'tokens': [{'text': 'contain', 'start': 0, 'end': 7, 'id': 0, 'ws': True},
#    {'text': 'detail', 'start': 8, 'end': 14, 'id': 1, 'ws': True},
#    {'text': 'transact', 'start': 15, 'end': 23, 'id': 2, 'ws': True},
#    {'text': 'between', 'start': 24, 'end': 31, 'id': 3, 'ws': True},
#    {'text': 'initi', 'start': 32, 'end': 37, 'id': 4, 'ws': True},
#    {'text': 'command', 'start': 38, 'end': 45, 'id': 5, 'ws': True},
#    {'text': 'for', 'start': 46, 'end': 49, 'id': 6, 'ws': True},
#    {'text': 'that', 'start': 50, 'end': 54, 'id': 7, 'ws': True},
#    {'text': 'transact', 'start': 55, 'end': 63, 'id': 8, 'ws': True},
#    {'text': 'initi', 'start': 64, 'end': 69, 'id': 9, 'ws': True},
#    {'text': 'command', 'start': 70, 'end': 77, 'id': 10, 'ws': True},
#    {'text': 'for', 'start': 78, 'end': 81, 'id': 11, 'ws': True},
#    {'text': 'next', 'start': 82, 'end': 86, 'id': 12, 'ws': True},
#    {'text': 'transact', 'start': 87, 'end': 95, 'id': 13, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': [],
#   'config': {'choice_style': 'single'},
#   'answer': 'reject',
#   '_timestamp': 1676984377},
#  {'text': 'contraind inform collect indic vaccin treatment or antidot may not administ or patient may not compli with prescrib intervent',
#   'spans': [],
#   'meta': {'pattern': '167'},
#   '_input_hash': 139608620,
#   '_task_hash': 711700686,
#   'tokens': [{'text': 'contraind', 'start': 0, 'end': 9, 'id': 0, 'ws': True},
#    {'text': 'inform', 'start': 10, 'end': 16, 'id': 1, 'ws': True},
#    {'text': 'collect', 'start': 17, 'end': 24, 'id': 2, 'ws': True},
#    {'text': 'indic', 'start': 25, 'end': 30, 'id': 3, 'ws': True},
#    {'text': 'vaccin', 'start': 31, 'end': 37, 'id': 4, 'ws': True},
#    {'text': 'treatment', 'start': 38, 'end': 47, 'id': 5, 'ws': True},
#    {'text': 'or', 'start': 48, 'end': 50, 'id': 6, 'ws': True},
#    {'text': 'antidot', 'start': 51, 'end': 58, 'id': 7, 'ws': True},
#    {'text': 'may', 'start': 59, 'end': 62, 'id': 8, 'ws': True},
#    {'text': 'not', 'start': 63, 'end': 66, 'id': 9, 'ws': True},
#    {'text': 'administ', 'start': 67, 'end': 75, 'id': 10, 'ws': True},
#    {'text': 'or', 'start': 76, 'end': 78, 'id': 11, 'ws': True},
#    {'text': 'patient', 'start': 79, 'end': 86, 'id': 12, 'ws': True},
#    {'text': 'may', 'start': 87, 'end': 90, 'id': 13, 'ws': True},
#    {'text': 'not', 'start': 91, 'end': 94, 'id': 14, 'ws': True},
#    {'text': 'compli', 'start': 95, 'end': 101, 'id': 15, 'ws': True},
#    {'text': 'with', 'start': 102, 'end': 106, 'id': 16, 'ws': True},
#    {'text': 'prescrib', 'start': 107, 'end': 115, 'id': 17, 'ws': True},
#    {'text': 'intervent', 'start': 116, 'end': 125, 'id': 18, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': [],
#   'config': {'choice_style': 'single'},
#   'answer': 'reject',
#   '_timestamp': 1676984383},
#  {'text': 'dpu icui shall provid icui_hk dpu ccm on request',
#   'spans': [{'start': 0,
#     'end': 8,
#     'token_start': 0,
#     'token_end': 1,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 48,
#     'token_start': 0,
#     'token_end': 8,
#     'label': 'POSTCONDITION'},
#    {'start': 22,
#     'end': 29,
#     'token_start': 4,
#     'token_end': 4,
#     'label': 'ACTOR'},
#    {'start': 30,
#     'end': 37,
#     'token_start': 0,
#     'token_end': 6,
#     'label': 'ACTOR'}],
#   'meta': {'pattern': ''},
#   '_input_hash': -244867918,
#   '_task_hash': -135964165,
#   'tokens': [{'text': 'dpu', 'start': 0, 'end': 3, 'id': 0, 'ws': True},
#    {'text': 'icui', 'start': 4, 'end': 8, 'id': 1, 'ws': True},
#    {'text': 'shall', 'start': 9, 'end': 14, 'id': 2, 'ws': True},
#    {'text': 'provid', 'start': 15, 'end': 21, 'id': 3, 'ws': True},
#    {'text': 'icui_hk', 'start': 22, 'end': 29, 'id': 4, 'ws': True},
#    {'text': 'dpu', 'start': 30, 'end': 33, 'id': 5, 'ws': True},
#    {'text': 'ccm', 'start': 34, 'end': 37, 'id': 6, 'ws': True},
#    {'text': 'on', 'start': 38, 'end': 40, 'id': 7, 'ws': True},
#    {'text': 'request', 'start': 41, 'end': 48, 'id': 8, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984548},
#  {'text': 'mmi shall suitabl for use by day night',
#   'spans': [{'start': 0,
#     'end': 38,
#     'token_start': 0,
#     'token_end': 7,
#     'label': 'POSTCONDITION'},
#    {'start': 0, 'end': 3, 'token_start': 0, 'token_end': 0, 'label': 'ACTOR'}],
#   'meta': {'pattern': ''},
#   '_input_hash': -667930023,
#   '_task_hash': -1861851007,
#   'tokens': [{'text': 'mmi', 'start': 0, 'end': 3, 'id': 0, 'ws': True},
#    {'text': 'shall', 'start': 4, 'end': 9, 'id': 1, 'ws': True},
#    {'text': 'suitabl', 'start': 10, 'end': 17, 'id': 2, 'ws': True},
#    {'text': 'for', 'start': 18, 'end': 21, 'id': 3, 'ws': True},
#    {'text': 'use', 'start': 22, 'end': 25, 'id': 4, 'ws': True},
#    {'text': 'by', 'start': 26, 'end': 28, 'id': 5, 'ws': True},
#    {'text': 'day', 'start': 29, 'end': 32, 'id': 6, 'ws': True},
#    {'text': 'night', 'start': 33, 'end': 38, 'id': 7, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984548},
#  {'text': 'dpu scui shall provid capabl for data produc applic specifi whether or not queu data may segment',
#   'spans': [{'start': 0,
#     'end': 8,
#     'token_start': 0,
#     'token_end': 1,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 96,
#     'token_start': 0,
#     'token_end': 16,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 719975244,
#   '_task_hash': 838261475,
#   'tokens': [{'text': 'dpu', 'start': 0, 'end': 3, 'id': 0, 'ws': True},
#    {'text': 'scui', 'start': 4, 'end': 8, 'id': 1, 'ws': True},
#    {'text': 'shall', 'start': 9, 'end': 14, 'id': 2, 'ws': True},
#    {'text': 'provid', 'start': 15, 'end': 21, 'id': 3, 'ws': True},
#    {'text': 'capabl', 'start': 22, 'end': 28, 'id': 4, 'ws': True},
#    {'text': 'for', 'start': 29, 'end': 32, 'id': 5, 'ws': True},
#    {'text': 'data', 'start': 33, 'end': 37, 'id': 6, 'ws': True},
#    {'text': 'produc', 'start': 38, 'end': 44, 'id': 7, 'ws': True},
#    {'text': 'applic', 'start': 45, 'end': 51, 'id': 8, 'ws': True},
#    {'text': 'specifi', 'start': 52, 'end': 59, 'id': 9, 'ws': True},
#    {'text': 'whether', 'start': 60, 'end': 67, 'id': 10, 'ws': True},
#    {'text': 'or', 'start': 68, 'end': 70, 'id': 11, 'ws': True},
#    {'text': 'not', 'start': 71, 'end': 74, 'id': 12, 'ws': True},
#    {'text': 'queu', 'start': 75, 'end': 79, 'id': 13, 'ws': True},
#    {'text': 'data', 'start': 80, 'end': 84, 'id': 14, 'ws': True},
#    {'text': 'may', 'start': 85, 'end': 88, 'id': 15, 'ws': True},
#    {'text': 'segment', 'start': 89, 'end': 96, 'id': 16, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984548},
#  {'text': 'in case multicast stream cng support proxi function optim manag inform relat signal',
#   'spans': [{'start': 0,
#     'end': 24,
#     'token_start': 0,
#     'token_end': 3,
#     'label': 'PRECONDITION'},
#    {'start': 25,
#     'end': 83,
#     'token_start': 4,
#     'token_end': 12,
#     'label': 'POSTCONDITION'},
#    {'start': 25,
#     'end': 28,
#     'token_start': 4,
#     'token_end': 4,
#     'label': 'ACTOR'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 1662628289,
#   '_task_hash': 1951469086,
#   'tokens': [{'text': 'in', 'start': 0, 'end': 2, 'id': 0, 'ws': True},
#    {'text': 'case', 'start': 3, 'end': 7, 'id': 1, 'ws': True},
#    {'text': 'multicast', 'start': 8, 'end': 17, 'id': 2, 'ws': True},
#    {'text': 'stream', 'start': 18, 'end': 24, 'id': 3, 'ws': True},
#    {'text': 'cng', 'start': 25, 'end': 28, 'id': 4, 'ws': True},
#    {'text': 'support', 'start': 29, 'end': 36, 'id': 5, 'ws': True},
#    {'text': 'proxi', 'start': 37, 'end': 42, 'id': 6, 'ws': True},
#    {'text': 'function', 'start': 43, 'end': 51, 'id': 7, 'ws': True},
#    {'text': 'optim', 'start': 52, 'end': 57, 'id': 8, 'ws': True},
#    {'text': 'manag', 'start': 58, 'end': 63, 'id': 9, 'ws': True},
#    {'text': 'inform', 'start': 64, 'end': 70, 'id': 10, 'ws': True},
#    {'text': 'relat', 'start': 71, 'end': 76, 'id': 11, 'ws': True},
#    {'text': 'signal', 'start': 77, 'end': 83, 'id': 12, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['BOTH'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984549},
#  {'text': 'etc trainborn equip shall indic on dmi inform regard pantograph power suppli',
#   'spans': [{'start': 0,
#     'end': 3,
#     'token_start': 0,
#     'token_end': 0,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 76,
#     'token_start': 0,
#     'token_end': 11,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': '49'},
#   '_input_hash': -796757328,
#   '_task_hash': -1129430911,
#   'tokens': [{'text': 'etc', 'start': 0, 'end': 3, 'id': 0, 'ws': True},
#    {'text': 'trainborn', 'start': 4, 'end': 13, 'id': 1, 'ws': True},
#    {'text': 'equip', 'start': 14, 'end': 19, 'id': 2, 'ws': True},
#    {'text': 'shall', 'start': 20, 'end': 25, 'id': 3, 'ws': True},
#    {'text': 'indic', 'start': 26, 'end': 31, 'id': 4, 'ws': True},
#    {'text': 'on', 'start': 32, 'end': 34, 'id': 5, 'ws': True},
#    {'text': 'dmi', 'start': 35, 'end': 38, 'id': 6, 'ws': True},
#    {'text': 'inform', 'start': 39, 'end': 45, 'id': 7, 'ws': True},
#    {'text': 'regard', 'start': 46, 'end': 52, 'id': 8, 'ws': True},
#    {'text': 'pantograph', 'start': 53, 'end': 63, 'id': 9, 'ws': True},
#    {'text': 'power', 'start': 64, 'end': 69, 'id': 10, 'ws': True},
#    {'text': 'suppli', 'start': 70, 'end': 76, 'id': 11, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984549},
#  {'text': 'dpu edac shall record current content edac_hk eeprom forc dpu watchdog in event mbe in dram detect',
#   'spans': [{'start': 0,
#     'end': 8,
#     'token_start': 0,
#     'token_end': 1,
#     'label': 'ACTOR'},
#    {'start': 0,
#     'end': 98,
#     'token_start': 0,
#     'token_end': 16,
#     'label': 'POSTCONDITION'}],
#   'meta': {'pattern': ''},
#   '_input_hash': -1305572948,
#   '_task_hash': 1147454653,
#   'tokens': [{'text': 'dpu', 'start': 0, 'end': 3, 'id': 0, 'ws': True},
#    {'text': 'edac', 'start': 4, 'end': 8, 'id': 1, 'ws': True},
#    {'text': 'shall', 'start': 9, 'end': 14, 'id': 2, 'ws': True},
#    {'text': 'record', 'start': 15, 'end': 21, 'id': 3, 'ws': True},
#    {'text': 'current', 'start': 22, 'end': 29, 'id': 4, 'ws': True},
#    {'text': 'content', 'start': 30, 'end': 37, 'id': 5, 'ws': True},
#    {'text': 'edac_hk', 'start': 38, 'end': 45, 'id': 6, 'ws': True},
#    {'text': 'eeprom', 'start': 46, 'end': 52, 'id': 7, 'ws': True},
#    {'text': 'forc', 'start': 53, 'end': 57, 'id': 8, 'ws': True},
#    {'text': 'dpu', 'start': 58, 'end': 61, 'id': 9, 'ws': True},
#    {'text': 'watchdog', 'start': 62, 'end': 70, 'id': 10, 'ws': True},
#    {'text': 'in', 'start': 71, 'end': 73, 'id': 11, 'ws': True},
#    {'text': 'event', 'start': 74, 'end': 79, 'id': 12, 'ws': True},
#    {'text': 'mbe', 'start': 80, 'end': 83, 'id': 13, 'ws': True},
#    {'text': 'in', 'start': 84, 'end': 86, 'id': 14, 'ws': True},
#    {'text': 'dram', 'start': 87, 'end': 91, 'id': 15, 'ws': True},
#    {'text': 'detect', 'start': 92, 'end': 98, 'id': 16, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1676984550},
#  {'text': 'in imag mode dpu dpa shall capabl bin imag differ level',
#   'spans': [{'start': 0,
#     'end': 12,
#     'token_start': 0,
#     'token_end': 2,
#     'label': 'PRECONDITION'},
#    {'start': 13,
#     'end': 55,
#     'token_start': 3,
#     'token_end': 10,
#     'label': 'POSTCONDITION'},
#    {'start': 13,
#     'end': 20,
#     'token_start': 3,
#     'token_end': 4,
#     'label': 'ACTOR'}],
#   'meta': {'pattern': ''},
#   '_input_hash': 1962170184,
#   '_task_hash': -609166348,
#   'tokens': [{'text': 'in', 'start': 0, 'end': 2, 'id': 0, 'ws': True},
#    {'text': 'imag', 'start': 3, 'end': 7, 'id': 1, 'ws': True},
#    {'text': 'mode', 'start': 8, 'end': 12, 'id': 2, 'ws': True},
#    {'text': 'dpu', 'start': 13, 'end': 16, 'id': 3, 'ws': True},
#    {'text': 'dpa', 'start': 17, 'end': 20, 'id': 4, 'ws': True},
#    {'text': 'shall', 'start': 21, 'end': 26, 'id': 5, 'ws': True},
#    {'text': 'capabl', 'start': 27, 'end': 33, 'id': 6, 'ws': True},
#    {'text': 'bin', 'start': 34, 'end': 37, 'id': 7, 'ws': True},
#    {'text': 'imag', 'start': 38, 'end': 42, 'id': 8, 'ws': True},
#    {'text': 'differ', 'start': 43, 'end': 49, 'id': 9, 'ws': True},
#    {'text': 'level', 'start': 50, 'end': 55, 'id': 10, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_view_id': 'blocks',
#   'accept': ['BOTH'],
# ...
#    {'text': 'go', 'start': 45, 'end': 47, 'id': 8, 'ws': True},
#    {'text': 'user', 'start': 48, 'end': 52, 'id': 9, 'ws': True},
#    {'text': 'in', 'start': 53, 'end': 55, 'id': 10, 'ws': True},
#    {'text': 'under', 'start': 56, 'end': 61, 'id': 11, 'ws': True},
#    {'text': '5', 'start': 62, 'end': 63, 'id': 12, 'ws': True},
#    {'text': 'minut', 'start': 64, 'end': 69, 'id': 13, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_input_hash': -767973224,
#   '_task_hash': 1754804738,
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'spans': [{'start': 0,
#     'end': 69,
#     'token_start': 0,
#     'token_end': 13,
#     'label': 'POSTCONDITION'},
#    {'start': 0, 'end': 6, 'token_start': 0, 'token_end': 0, 'label': 'ACTOR'},
#    {'start': 53,
#     'end': 69,
#     'token_start': 10,
#     'token_end': 13,
#     'label': 'QUALITY'}],
#   'answer': 'accept',
#   '_timestamp': 1677332754},
#  {'text': 'for both select by name first or onli occurr command select by name next occurr command applic becom select applic on basic logic channel if request aid match fulli or partial applic aid applic select in correct life cycl state applic restrict due multi select support current card interfac',
#   'tokens': [{'text': 'for', 'start': 0, 'end': 3, 'id': 0, 'ws': True},
#    {'text': 'both', 'start': 4, 'end': 8, 'id': 1, 'ws': True},
#    {'text': 'select', 'start': 9, 'end': 15, 'id': 2, 'ws': True},
#    {'text': 'by', 'start': 16, 'end': 18, 'id': 3, 'ws': True},
#    {'text': 'name', 'start': 19, 'end': 23, 'id': 4, 'ws': True},
#    {'text': 'first', 'start': 24, 'end': 29, 'id': 5, 'ws': True},
#    {'text': 'or', 'start': 30, 'end': 32, 'id': 6, 'ws': True},
#    {'text': 'onli', 'start': 33, 'end': 37, 'id': 7, 'ws': True},
#    {'text': 'occurr', 'start': 38, 'end': 44, 'id': 8, 'ws': True},
#    {'text': 'command', 'start': 45, 'end': 52, 'id': 9, 'ws': True},
#    {'text': 'select', 'start': 53, 'end': 59, 'id': 10, 'ws': True},
#    {'text': 'by', 'start': 60, 'end': 62, 'id': 11, 'ws': True},
#    {'text': 'name', 'start': 63, 'end': 67, 'id': 12, 'ws': True},
#    {'text': 'next', 'start': 68, 'end': 72, 'id': 13, 'ws': True},
#    {'text': 'occurr', 'start': 73, 'end': 79, 'id': 14, 'ws': True},
#    {'text': 'command', 'start': 80, 'end': 87, 'id': 15, 'ws': True},
#    {'text': 'applic', 'start': 88, 'end': 94, 'id': 16, 'ws': True},
#    {'text': 'becom', 'start': 95, 'end': 100, 'id': 17, 'ws': True},
#    {'text': 'select', 'start': 101, 'end': 107, 'id': 18, 'ws': True},
#    {'text': 'applic', 'start': 108, 'end': 114, 'id': 19, 'ws': True},
#    {'text': 'on', 'start': 115, 'end': 117, 'id': 20, 'ws': True},
#    {'text': 'basic', 'start': 118, 'end': 123, 'id': 21, 'ws': True},
#    {'text': 'logic', 'start': 124, 'end': 129, 'id': 22, 'ws': True},
#    {'text': 'channel', 'start': 130, 'end': 137, 'id': 23, 'ws': True},
#    {'text': 'if', 'start': 138, 'end': 140, 'id': 24, 'ws': True},
#    {'text': 'request', 'start': 141, 'end': 148, 'id': 25, 'ws': True},
#    {'text': 'aid', 'start': 149, 'end': 152, 'id': 26, 'ws': True},
#    {'text': 'match', 'start': 153, 'end': 158, 'id': 27, 'ws': True},
#    {'text': 'fulli', 'start': 159, 'end': 164, 'id': 28, 'ws': True},
#    {'text': 'or', 'start': 165, 'end': 167, 'id': 29, 'ws': True},
#    {'text': 'partial', 'start': 168, 'end': 175, 'id': 30, 'ws': True},
#    {'text': 'applic', 'start': 176, 'end': 182, 'id': 31, 'ws': True},
#    {'text': 'aid', 'start': 183, 'end': 186, 'id': 32, 'ws': True},
#    {'text': 'applic', 'start': 187, 'end': 193, 'id': 33, 'ws': True},
#    {'text': 'select', 'start': 194, 'end': 200, 'id': 34, 'ws': True},
#    {'text': 'in', 'start': 201, 'end': 203, 'id': 35, 'ws': True},
#    {'text': 'correct', 'start': 204, 'end': 211, 'id': 36, 'ws': True},
#    {'text': 'life', 'start': 212, 'end': 216, 'id': 37, 'ws': True},
#    {'text': 'cycl', 'start': 217, 'end': 221, 'id': 38, 'ws': True},
#    {'text': 'state', 'start': 222, 'end': 227, 'id': 39, 'ws': True},
#    {'text': 'applic', 'start': 228, 'end': 234, 'id': 40, 'ws': True},
#    {'text': 'restrict', 'start': 235, 'end': 243, 'id': 41, 'ws': True},
#    {'text': 'due', 'start': 244, 'end': 247, 'id': 42, 'ws': True},
#    {'text': 'multi', 'start': 248, 'end': 253, 'id': 43, 'ws': True},
#    {'text': 'select', 'start': 254, 'end': 260, 'id': 44, 'ws': True},
#    {'text': 'support', 'start': 261, 'end': 268, 'id': 45, 'ws': True},
#    {'text': 'current', 'start': 269, 'end': 276, 'id': 46, 'ws': True},
#    {'text': 'card', 'start': 277, 'end': 281, 'id': 47, 'ws': True},
#    {'text': 'interfac', 'start': 282, 'end': 290, 'id': 48, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_input_hash': -1547820840,
#   '_task_hash': 422838085,
#   '_view_id': 'blocks',
#   'accept': ['BOTH'],
#   'config': {'choice_style': 'single'},
#   'spans': [{'start': 0,
#     'end': 87,
#     'token_start': 0,
#     'token_end': 9,
#     'label': 'PRECONDITION'},
#    {'start': 88,
#     'end': 137,
#     'token_start': 16,
#     'token_end': 23,
#     'label': 'POSTCONDITION'},
#    {'start': 138,
#     'end': 186,
#     'token_start': 24,
#     'token_end': 26,
#     'label': 'PRECONDITION'},
#    {'start': 141,
#     'end': 152,
#     'token_start': 25,
#     'token_end': 26,
#     'label': 'ACTOR'},
#    {'start': 187,
#     'end': 227,
#     'token_start': 16,
#     'token_end': 39,
#     'label': 'POSTCONDITION'},
#    {'start': 88,
#     'end': 94,
#     'token_start': 16,
#     'token_end': 16,
#     'label': 'ACTOR'},
#    {'start': 228,
#     'end': 260,
#     'token_start': 16,
#     'token_end': 2,
#     'label': 'POSTCONDITION'},
#    {'start': 88,
#     'end': 94,
#     'token_start': 16,
#     'token_end': 16,
#     'label': 'ACTOR'},
#    {'start': 261,
#     'end': 290,
#     'token_start': 45,
#     'token_end': 48,
#     'label': 'POSTCONDITION'}],
#   'answer': 'accept',
#   '_timestamp': 1677332755},
#  {'text': 'user access limit permiss grant role each level in pcg hierarchi will assign role user will assign these role access function within rf system depend on privileg permiss assign role',
#   'tokens': [{'text': 'user', 'start': 0, 'end': 4, 'id': 0, 'ws': True},
#    {'text': 'access', 'start': 5, 'end': 11, 'id': 1, 'ws': True},
#    {'text': 'limit', 'start': 12, 'end': 17, 'id': 2, 'ws': True},
#    {'text': 'permiss', 'start': 18, 'end': 25, 'id': 3, 'ws': True},
#    {'text': 'grant', 'start': 26, 'end': 31, 'id': 4, 'ws': True},
#    {'text': 'role', 'start': 32, 'end': 36, 'id': 5, 'ws': True},
#    {'text': 'each', 'start': 37, 'end': 41, 'id': 6, 'ws': True},
#    {'text': 'level', 'start': 42, 'end': 47, 'id': 7, 'ws': True},
#    {'text': 'in', 'start': 48, 'end': 50, 'id': 8, 'ws': True},
#    {'text': 'pcg', 'start': 51, 'end': 54, 'id': 9, 'ws': True},
#    {'text': 'hierarchi', 'start': 55, 'end': 64, 'id': 10, 'ws': True},
#    {'text': 'will', 'start': 65, 'end': 69, 'id': 11, 'ws': True},
#    {'text': 'assign', 'start': 70, 'end': 76, 'id': 12, 'ws': True},
#    {'text': 'role', 'start': 77, 'end': 81, 'id': 13, 'ws': True},
#    {'text': 'user', 'start': 82, 'end': 86, 'id': 14, 'ws': True},
#    {'text': 'will', 'start': 87, 'end': 91, 'id': 15, 'ws': True},
#    {'text': 'assign', 'start': 92, 'end': 98, 'id': 16, 'ws': True},
#    {'text': 'these', 'start': 99, 'end': 104, 'id': 17, 'ws': True},
#    {'text': 'role', 'start': 105, 'end': 109, 'id': 18, 'ws': True},
#    {'text': 'access', 'start': 110, 'end': 116, 'id': 19, 'ws': True},
#    {'text': 'function', 'start': 117, 'end': 125, 'id': 20, 'ws': True},
#    {'text': 'within', 'start': 126, 'end': 132, 'id': 21, 'ws': True},
#    {'text': 'rf', 'start': 133, 'end': 135, 'id': 22, 'ws': True},
#    {'text': 'system', 'start': 136, 'end': 142, 'id': 23, 'ws': True},
#    {'text': 'depend', 'start': 143, 'end': 149, 'id': 24, 'ws': True},
#    {'text': 'on', 'start': 150, 'end': 152, 'id': 25, 'ws': True},
#    {'text': 'privileg', 'start': 153, 'end': 161, 'id': 26, 'ws': True},
#    {'text': 'permiss', 'start': 162, 'end': 169, 'id': 27, 'ws': True},
#    {'text': 'assign', 'start': 170, 'end': 176, 'id': 28, 'ws': True},
#    {'text': 'role', 'start': 177, 'end': 181, 'id': 29, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_input_hash': -1733958835,
#   '_task_hash': 303532833,
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'spans': [{'start': 0,
#     'end': 109,
#     'token_start': 0,
#     'token_end': 5,
#     'label': 'POSTCONDITION'},
#    {'start': 0, 'end': 11, 'token_start': 0, 'token_end': 1, 'label': 'ACTOR'},
#    {'start': 51,
#     'end': 54,
#     'token_start': 9,
#     'token_end': 9,
#     'label': 'ACTOR'}],
#   'answer': 'accept',
#   '_timestamp': 1677332757},
#  {'text': 'termin must secur transact by retain card symmetr mace key signatur part transact',
#   'tokens': [{'text': 'termin', 'start': 0, 'end': 6, 'id': 0, 'ws': True},
#    {'text': 'must', 'start': 7, 'end': 11, 'id': 1, 'ws': True},
#    {'text': 'secur', 'start': 12, 'end': 17, 'id': 2, 'ws': True},
#    {'text': 'transact', 'start': 18, 'end': 26, 'id': 3, 'ws': True},
#    {'text': 'by', 'start': 27, 'end': 29, 'id': 4, 'ws': True},
#    {'text': 'retain', 'start': 30, 'end': 36, 'id': 5, 'ws': True},
#    {'text': 'card', 'start': 37, 'end': 41, 'id': 6, 'ws': True},
#    {'text': 'symmetr', 'start': 42, 'end': 49, 'id': 7, 'ws': True},
#    {'text': 'mace', 'start': 50, 'end': 54, 'id': 8, 'ws': True},
#    {'text': 'key', 'start': 55, 'end': 58, 'id': 9, 'ws': True},
#    {'text': 'signatur', 'start': 59, 'end': 67, 'id': 10, 'ws': True},
#    {'text': 'part', 'start': 68, 'end': 72, 'id': 11, 'ws': True},
#    {'text': 'transact', 'start': 73, 'end': 81, 'id': 12, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_input_hash': -107426493,
#   '_task_hash': -1299888735,
#   '_view_id': 'blocks',
#   'accept': ['POSTCONDITION'],
#   'config': {'choice_style': 'single'},
#   'spans': [{'start': 0,
#     'end': 81,
#     'token_start': 0,
#     'token_end': 3,
#     'label': 'POSTCONDITION'},
#    {'start': 0, 'end': 6, 'token_start': 0, 'token_end': 0, 'label': 'ACTOR'},
#    {'start': 37,
#     'end': 49,
#     'token_start': 6,
#     'token_end': 7,
#     'label': 'ACTOR'}],
#   'answer': 'accept',
#   '_timestamp': 1677332759},
#  {'text': 'perform calcul requir gener signatur use psam privat rsa key allow cep card valid psam',
#   'tokens': [{'text': 'perform', 'start': 0, 'end': 7, 'id': 0, 'ws': True},
#    {'text': 'calcul', 'start': 8, 'end': 14, 'id': 1, 'ws': True},
#    {'text': 'requir', 'start': 15, 'end': 21, 'id': 2, 'ws': True},
#    {'text': 'gener', 'start': 22, 'end': 27, 'id': 3, 'ws': True},
#    {'text': 'signatur', 'start': 28, 'end': 36, 'id': 4, 'ws': True},
#    {'text': 'use', 'start': 37, 'end': 40, 'id': 5, 'ws': True},
#    {'text': 'psam', 'start': 41, 'end': 45, 'id': 6, 'ws': True},
#    {'text': 'privat', 'start': 46, 'end': 52, 'id': 7, 'ws': True},
#    {'text': 'rsa', 'start': 53, 'end': 56, 'id': 8, 'ws': True},
#    {'text': 'key', 'start': 57, 'end': 60, 'id': 9, 'ws': True},
#    {'text': 'allow', 'start': 61, 'end': 66, 'id': 10, 'ws': True},
#    {'text': 'cep', 'start': 67, 'end': 70, 'id': 11, 'ws': True},
#    {'text': 'card', 'start': 71, 'end': 75, 'id': 12, 'ws': True},
#    {'text': 'valid', 'start': 76, 'end': 81, 'id': 13, 'ws': True},
#    {'text': 'psam', 'start': 82, 'end': 86, 'id': 14, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_input_hash': 908592651,
#   '_task_hash': -1203842183,
#   '_view_id': 'blocks',
#   'config': {'choice_style': 'single'},
#   'accept': [],
#   'answer': 'accept',
#   '_timestamp': 1677332766,
#   'spans': []},
#  {'text': 'card issuer gener s2 which sent card allow card valid card issuer authent ensur that data use by card in transact card issuer intend',
#   'tokens': [{'text': 'card', 'start': 0, 'end': 4, 'id': 0, 'ws': True},
#    {'text': 'issuer', 'start': 5, 'end': 11, 'id': 1, 'ws': True},
#    {'text': 'gener', 'start': 12, 'end': 17, 'id': 2, 'ws': True},
#    {'text': 's2', 'start': 18, 'end': 20, 'id': 3, 'ws': True},
#    {'text': 'which', 'start': 21, 'end': 26, 'id': 4, 'ws': True},
#    {'text': 'sent', 'start': 27, 'end': 31, 'id': 5, 'ws': True},
#    {'text': 'card', 'start': 32, 'end': 36, 'id': 6, 'ws': True},
#    {'text': 'allow', 'start': 37, 'end': 42, 'id': 7, 'ws': True},
#    {'text': 'card', 'start': 43, 'end': 47, 'id': 8, 'ws': True},
#    {'text': 'valid', 'start': 48, 'end': 53, 'id': 9, 'ws': True},
#    {'text': 'card', 'start': 54, 'end': 58, 'id': 10, 'ws': True},
#    {'text': 'issuer', 'start': 59, 'end': 65, 'id': 11, 'ws': True},
#    {'text': 'authent', 'start': 66, 'end': 73, 'id': 12, 'ws': True},
#    {'text': 'ensur', 'start': 74, 'end': 79, 'id': 13, 'ws': True},
#    {'text': 'that', 'start': 80, 'end': 84, 'id': 14, 'ws': True},
#    {'text': 'data', 'start': 85, 'end': 89, 'id': 15, 'ws': True},
#    {'text': 'use', 'start': 90, 'end': 93, 'id': 16, 'ws': True},
#    {'text': 'by', 'start': 94, 'end': 96, 'id': 17, 'ws': True},
#    {'text': 'card', 'start': 97, 'end': 101, 'id': 18, 'ws': True},
#    {'text': 'in', 'start': 102, 'end': 104, 'id': 19, 'ws': True},
#    {'text': 'transact', 'start': 105, 'end': 113, 'id': 20, 'ws': True},
#    {'text': 'card', 'start': 114, 'end': 118, 'id': 21, 'ws': True},
#    {'text': 'issuer', 'start': 119, 'end': 125, 'id': 22, 'ws': True},
#    {'text': 'intend', 'start': 126, 'end': 132, 'id': 23, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_input_hash': 1359999743,
#   '_task_hash': -1956937589,
#   '_view_id': 'blocks',
#   'accept': [],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1677332777,
#   'spans': []},
#  {'text': 'if select by name first or onli occurr receiv search alway begin from start globalplatform registri',
#   'tokens': [{'text': 'if', 'start': 0, 'end': 2, 'id': 0, 'ws': True},
#    {'text': 'select', 'start': 3, 'end': 9, 'id': 1, 'ws': True},
#    {'text': 'by', 'start': 10, 'end': 12, 'id': 2, 'ws': True},
#    {'text': 'name', 'start': 13, 'end': 17, 'id': 3, 'ws': True},
#    {'text': 'first', 'start': 18, 'end': 23, 'id': 4, 'ws': True},
#    {'text': 'or', 'start': 24, 'end': 26, 'id': 5, 'ws': True},
#    {'text': 'onli', 'start': 27, 'end': 31, 'id': 6, 'ws': True},
#    {'text': 'occurr', 'start': 32, 'end': 38, 'id': 7, 'ws': True},
#    {'text': 'receiv', 'start': 39, 'end': 45, 'id': 8, 'ws': True},
#    {'text': 'search', 'start': 46, 'end': 52, 'id': 9, 'ws': True},
#    {'text': 'alway', 'start': 53, 'end': 58, 'id': 10, 'ws': True},
#    {'text': 'begin', 'start': 59, 'end': 64, 'id': 11, 'ws': True},
#    {'text': 'from', 'start': 65, 'end': 69, 'id': 12, 'ws': True},
#    {'text': 'start', 'start': 70, 'end': 75, 'id': 13, 'ws': True},
#    {'text': 'globalplatform', 'start': 76, 'end': 90, 'id': 14, 'ws': True},
#    {'text': 'registri', 'start': 91, 'end': 99, 'id': 15, 'ws': False}],
#   'options': [{'id': 'NONE', 'text': 'NONE'},
#    {'id': 'PRECONDITION', 'text': 'PRECONDITION'},
#    {'id': 'POSTCONDITION', 'text': 'POSTCONDITION'},
#    {'id': 'BOTH', 'text': 'BOTH'}],
#   '_input_hash': 639109096,
#   '_task_hash': 139804703,
#   '_view_id': 'blocks',
#   'accept': [],
#   'config': {'choice_style': 'single'},
#   'answer': 'accept',
#   '_timestamp': 1677332779,
#   'spans': []}]
